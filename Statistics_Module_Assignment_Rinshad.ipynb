# %% [markdown]
# <a id='1'></a><center> <h3 style="background-color:orange; color:white" ><br>Telecommunication Industry Project<br></h3>

# %% [markdown]
# # Introduction
# This Jupyter notebook is part of your learning experience in the study of applied statistics.
#
# You will work with a data set that contains mobile phone prices and their specifications.
#
# **Dataset Columns Information**
#
# PID = a unique identifier for the phone model
#
# Blue = whether the phone has bluetooth support or not
#
# Wi_Fi = whether the phone has wifi support or not
#
# Tch_Scr = whether the phone has touch screen support or not
#
# Ext_Mem = whether the phone has external memory support or not
#
# Px_h = number of pixels in the vertical axis of the phone
#
# Px_w = number of pixels in the horizontal axis of the phone
#
# Scr_h = height of the screen of the phone in centimetres (cm)
#
# Scr_w = width of the screen of the phone in centimetres (cm)
#
# Int_Mem = internal memory of the phone measured in megabytes (MB)
#
# Bty_Pwr = maximum energy stored by the phone's battery measured in
# milli-Ampere-hours (mAh)
#
# PC = resolution of the primary camera measued in megapixels (MP)
#
# FC = resolution of the front camera measued in megapixels (MP)
#
# RAM = random access memory available in the phone measured in gigabytes (GB)
#
# Depth = depth of the mobile phone measured in centimetres (cm)
#
# Weight = weight of the mobile phone measured in grams (g)
#
# Price = selling price of the mobile phone in rupees

# %% [markdown]
# ## Task 1 - Load and study the data

# %% [markdown]
# Import the libraries that will be used in this notebook

# %%
# Load "numpy" and "pandas" for manipulating numbers and data frames
# Load "matplotlib.pyplot" and "seaborn" for data visualisation

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/content/Telecom Dataset.csv")

print(df.shape)
# Out:
# (50, 17)

# %% [markdown]
# Load the csv file as pandas dataframe.

# %%
# Read in the "Dataset" file as a Pandas Data Frame

df = pd.read_csv("C:/Users/user!/OneDrive/Desktop/Telecom Dataset.py.csv")
print("Dataset loaded successfully!")
print("Shape:", df.shape)
# Out:
# Dataset loaded successfully!
# Shape: (50, 17)

# %%
# Take a brief look at the data
print(df.head())
print(df.tail())
print(df.info())
print(df.describe())
print(df.isnull(). sum())
# Out:
#        PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w  PC  FC  \
# 0  AAB346A  yes   yes      no      no   780   460      3      1   2   2
# 1  AAC347I  yes   yes      no      no   780   560      2      1   4   2
# 2  BAB657J   no   yes      no      no   840   720      2      1   4   2
# 3  BBD456K   no   yes     yes      no  1280  1120      5      3   6   2
# 4  CCP761U   no   yes     yes      no  1280  1080      4      3   6   2
#
#    Int_Mem  Bty_Pwr  RAM  Depth  Weight  Price
# 0        8     2800    2      7     320   3297
# 1        8     3000    2      7     280   4500
# 2        8     3300    2      7     400   4898
# 3       32     3000    2      3     300   6900
# 4       16     3000    2      3     210   5600
#         PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w   PC  FC  \
# 45  XXV567F   no   yes     yes     yes  2580  1980      8      6   64  32
# 46  YTR67TY  yes   yes     yes     yes  2580  1980      4      3   64  32
# 47  ZDF789K  yes   yes     yes      no  2880  2520      8      6   64  32
# 48  ZEO567M  yes   yes     yes      no  2880  2520      8      6  128  64
# 49  ZZZ909X  yes   yes     yes      no  2880  2520      8      6  128  64
#
#     Int_Mem  Bty_Pwr  RAM  Depth  Weight   Price
# 45       64     2300    4      3     250   43990
# 46       64     2800    4      3     200   56000
# 47      512     5600   12      2      80   84566
# 48      512     5600   12      2     110   88999
# 49     1024     5600   12      2     130  149000
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PID      50 non-null     str
#  1   Blue     50 non-null     str
#  2   Wi_Fi    50 non-null     str
#  3   Tch_Scr  50 non-null     str
#  4   Ext_Mem  50 non-null     str
#  5   Px_h     50 non-null     int64
#  6   Px_w     50 non-null     int64
#  7   Scr_h    50 non-null     int64
#  8   Scr_w    50 non-null     int64
#  9   PC       50 non-null     int64
#  10  FC       50 non-null     int64
#  11  Int_Mem  50 non-null     int64
#  12  Bty_Pwr  50 non-null     int64
#  13  RAM      50 non-null     int64
#  14  Depth    50 non-null     int64
#  15  Weight   50 non-null     int64
#  16  Price    50 non-null     int64
# dtypes: int64(12), str(5)
# memory usage: 6.8 KB
# None
#               Px_h         Px_w      Scr_h      Scr_w          PC         FC  \
# count    50.000000    50.000000  50.000000  50.000000   50.000000  50.000000
# mean   2319.400000  1833.200000   6.500000   4.620000   42.160000  20.760000
# std     598.400623   469.713069   2.042907   1.883223   30.174567  14.784934
# min     780.000000   460.000000   2.000000   1.000000    2.000000   2.000000
# 25%    2080.000000  1775.000000   5.000000   3.000000   12.000000   8.000000
# 50%    2580.000000  1980.000000   6.000000   5.000000   40.000000  16.000000
# 75%    2580.000000  2120.000000   8.000000   6.000000   64.000000  32.000000
# max    2880.000000  2520.000000  10.000000   8.000000  128.000000  64.000000
#
#            Int_Mem      Bty_Pwr        RAM      Depth      Weight  \
# count    50.000000    50.000000  50.000000  50.000000   50.000000
# mean    173.760000  3740.000000   5.760000   3.440000  195.200000
# std     261.771871   958.817299   2.759473   1.052887   75.761171
# min       8.000000  2300.000000   2.000000   2.000000   80.000000
# 25%      32.000000  2800.000000   4.000000   3.000000  142.500000
# 50%      64.000000  3300.000000   5.000000   3.000000  190.000000
# 75%     128.000000  4500.000000   8.000000   4.000000  247.500000
# max    1024.000000  5600.000000  12.000000   7.000000  400.000000
#
#                Price
# count      50.000000
# mean    33794.860000
# std     25037.535393
# min      3297.000000
# 25%     19126.500000
# 50%     29349.500000
# 75%     43560.000000
# max    149000.000000
# PID        0
# Blue       0
# Wi_Fi      0
# Tch_Scr    0
# Ext_Mem    0
# Px_h       0
# Px_w       0
# Scr_h      0
# Scr_w      0
# PC         0
# FC         0
# Int_Mem    0
# Bty_Pwr    0
# RAM        0
# Depth      0
# Weight     0
# Price      0
# dtype: int64

# %%
# Get the dimensions of the dataframe

print("Dimensions of the dataframe")
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
print("Total shape:", df.shape)
# Out:
# Dimensions of the dataframe
# Number of rows: 50
# Number of columns: 17
# Total shape: (50, 17)

# %%
# Get the row names of the dataframe
print('Row names(index):', df.index)
print("Total row:", len(df.index))
# Out:
# Row names(index): RangeIndex(start=0, stop=50, step=1)
# Total row: 50

# %%
# Get the column names of the dataframe
print("Column names:", df.columns)
print("Total columns:", len(df.columns))
# Out:
# Column names: Index(['PID', 'Blue', 'Wi_Fi', 'Tch_Scr', 'Ext_Mem', 'Px_h', 'Px_w', 'Scr_h',
#        'Scr_w', 'PC', 'FC', 'Int_Mem', 'Bty_Pwr', 'RAM', 'Depth', 'Weight',
#        'Price'],
#       dtype='str')
# Total columns: 17

# %%
# Look at basic information about the dataframe

print("Basic information abouut the dataframe")
print(df.info())
# Out:
# Basic information abouut the dataframe
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PID      50 non-null     str
#  1   Blue     50 non-null     str
#  2   Wi_Fi    50 non-null     str
#  3   Tch_Scr  50 non-null     str
#  4   Ext_Mem  50 non-null     str
#  5   Px_h     50 non-null     int64
#  6   Px_w     50 non-null     int64
#  7   Scr_h    50 non-null     int64
#  8   Scr_w    50 non-null     int64
#  9   PC       50 non-null     int64
#  10  FC       50 non-null     int64
#  11  Int_Mem  50 non-null     int64
#  12  Bty_Pwr  50 non-null     int64
#  13  RAM      50 non-null     int64
#  14  Depth    50 non-null     int64
#  15  Weight   50 non-null     int64
#  16  Price    50 non-null     int64
# dtypes: int64(12), str(5)
# memory usage: 6.8 KB
# None

# %% [markdown]
# Observations:
#
# There are 50 phones in the data set.
#
# There are 17 features in the data set including the "PID" feature which is used as the row index labels.
#
# There are no missing values in the data set.

# %% [markdown]
# <center>Let's try some logical operators to filter the data.<center>

# %% [markdown]
# ![](https://th.bing.com/th/id/R.0592084daa6518e4fae97f47217ec69e?rik=vNqmiaTVSSo54w&riu=http%3a%2f%2f2.bp.blogspot.com%2f-ujABms6N-Cg%2fTyYwShdTjnI%2fAAAAAAAAAAs%2fktPbHdifidc%2fs1600%2fLogical%2bOperators.PNG&ehk=ww1gl1HB2PcZwPQNHWRUvcQ631Q3mzyHSxL9G4zUKT4%3d&risl=&pid=ImgRaw&r=0,width=700,height=400)

# %% [markdown]
# ## Task 2 - Obtain the logical conditions for the features "Blue", "Wi_Fi", "Tch_Scr" and "Ext_Mem"

# %%
# Get the feature names of the dataframe

# %%
# Let's tackle these features: "Blue", "Wi_Fi", "Tch_Scr", "Ext_Mem"

# %%
# The children want phones that have the following: Bluetooth, WiFi, touch screen and external memory support
# Create a logical condition for this situation and store the logical values as "con1"

# %% [markdown]
# Observations:
#
# The features "Blue", "Wi_Fi", "Tch_Scr" and "Ext_Mem" are binary in nature.
#
# The children want all these features, so the logical condition "con1" has been obtained accordingly.

# %% [markdown]
# ## Task 3 - Obtain the logical conditions for the features "Px_h" and "Px_w"

# %%
# Get the feature names of the dataframe
print("All column names in the dataframe:")
print(df.columns.tolist())


print("Total columns: len(df.columns)")
# Out:
# All column names in the dataframe:
# ['PID', 'Blue', 'Wi_Fi', 'Tch_Scr', 'Ext_Mem', 'Px_h', 'Px_w', 'Scr_h', 'Scr_w', 'PC', 'FC', 'Int_Mem', 'Bty_Pwr', 'RAM', 'Depth', 'Weight', 'Price', 'Px']
# Total columns: len(df.columns)

# %%
# Let's tackle these features: "Px_h", "Px_w"

print("Statistics for Pixel Height (Px_h) and Pixel Width (Px_w):")
print("\nPx_h (Vertical Pixels):")
print(f"  Min: {df['Px_h'].min()}")
print(f"  Max: {df['Px_h'].max()}")
print(f"  Mean: {df['Px_h'].mean():.2f}")
print(f"  Median: {df['Px_h'].median()}")
print(f"  Std Dev: {df['Px_h'].std():.2f}")

print("\nPx_w (Horizontal Pixels):")
print(f"  Min: {df['Px_w'].min()}")
print(f"  Max: {df['Px_w'].max()}")
print(f"  Mean: {df['Px_w'].mean():.2f}")
print(f"  Median: {df['Px_w'].median()}")
print(f"  Std Dev: {df['Px_w'].std():.2f}")

print("\n" + "="*70)
print("Detailed Statistics:")
print(df[['Px_h', 'Px_w']].describe())
# Out:
# Statistics for Pixel Height (Px_h) and Pixel Width (Px_w):
#
# Px_h (Vertical Pixels):
#   Min: 780
#   Max: 2880
#   Mean: 2319.40
#   Median: 2580.0
#   Std Dev: 598.40
#
# Px_w (Horizontal Pixels):
#   Min: 460
#   Max: 2520
#   Mean: 1833.20
#   Median: 1980.0
#   Std Dev: 469.71
#
# ======================================================================
# Detailed Statistics:
#               Px_h         Px_w
# count    50.000000    50.000000
# mean   2319.400000  1833.200000
# std     598.400623   469.713069
# min     780.000000   460.000000
# 25%    2080.000000  1775.000000
# 50%    2580.000000  1980.000000
# 75%    2580.000000  2120.000000
# max    2880.000000  2520.000000

# %%
# Create a new feature called "Px" which stores the total resolution of the screen
df['Px'] = df['Px_h'] * df['Px_w']
print("New feature 'Px' (Total Screen Resolution) created!")
print("\nFirst 10 phones with their pixel resolution:")
print(df[['PID', 'Px_h', 'Px_w', 'Px']].head(10))

print("\n" + "="*70)
print("Statistics for Px (Total Resolution):")
print(df['Px'].describe())
# Out:
# New feature 'Px' (Total Screen Resolution) created!
#
# First 10 phones with their pixel resolution:
#        PID  Px_h  Px_w       Px
# 0  AAB346A   780   460   358800
# 1  AAC347I   780   560   436800
# 2  BAB657J   840   720   604800
# 3  BBD456K  1280  1120  1433600
# 4  CCP761U  1280  1080  1382400
# 5  CCQ674K  1280  1080  1382400
# 6  CTX123L  1390  1080  1501200
# 7  DFR256N  2880  2120  6105600
# 8  DGS789M  2580  1920  4953600
# 9  ENG897N  2580  1980  5108400
#
# ======================================================================
# Statistics for Px (Total Resolution):
# count    5.000000e+01
# mean     4.517184e+06
# std      1.800913e+06
# min      3.588000e+05
# 25%      3.696500e+06
# 50%      5.108400e+06
# 75%      5.469600e+06
# max      7.257600e+06
# Name: Px, dtype: float64

# %%
# Create a histogram of the "Px" feature and also show the mean and the median

plt.figure(figsize=(10, 6))
plt.hist(df['Px'], bins=15, color='skyblue', edgecolor='black', alpha=0.7)

mean_px = df['Px'].mean()
median_px = df['Px'].median()

plt.axvline(mean_px, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_px:.0f}')
plt.axvline(median_px, color='green', linestyle='--', linewidth=2, label=f'Median: {median_px:.0f}')

plt.xlabel('Total Screen Resolution (Px)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Distribution of Screen Resolution (Px_h × Px_w)', fontsize=14, fontweight='bold')
plt.legend(fontsize=11)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

print(f"Mean of Px: {mean_px:.2f}")
print(f"Median of Px: {median_px:.2f}")
print(f"Difference: {abs(mean_px - median_px):.2f}")
# Out:
# Mean of Px: 4517184.00
# Median of Px: 5108400.00
# Difference: 591216.00

# %%
# The children want phones that have good screen resolutions
# Consider the phones that have screen resolutions greater than or equal to the median value in the data set
# Create a logical condition for this situation and store the logical values as "con2"

median_px = df['Px'].median()
print(f"Median Screen Resolution (Px): {median_px}")

con2 = df['Px'] >= median_px

df['con2'] = con2

print(f"\nPhones with good screen resolution (Px >= {median_px}):")
print(con2.value_counts())

print(f"\nDetailed view (first 15 phones):")
print(df[['PID', 'Px_h', 'Px_w', 'Px', 'con2']].head(15))

print(f"\n" + "="*70)
print(f"Total phones with good resolution (con2=True): {con2.sum()}")
print(f"Total phones with poor resolution (con2=False): {(~con2).sum()}")
# Out:
# Median Screen Resolution (Px): 5108400.0
#
# Phones with good screen resolution (Px >= 5108400.0):
# Px
# True     30
# False    20
# Name: count, dtype: int64
#
# Detailed view (first 15 phones):
#         PID  Px_h  Px_w       Px   con2
# 0   AAB346A   780   460   358800  False
# 1   AAC347I   780   560   436800  False
# 2   BAB657J   840   720   604800  False
# 3   BBD456K  1280  1120  1433600  False
# 4   CCP761U  1280  1080  1382400  False
# 5   CCQ674K  1280  1080  1382400  False
# 6   CTX123L  1390  1080  1501200  False
# 7   DFR256N  2880  2120  6105600   True
# 8   DGS789M  2580  1920  4953600  False
# 9   ENG897N  2580  1980  5108400   True
# 10  EOP657N  2580  1920  4953600  False
# 11  ELS333L  2580  1920  4953600  False
# 12  ETT987D  2580  1980  5108400   True
# 13  NAJ56GL  2880  2120  6105600   True
# 14  NBN329S  2380  1820  4331600  False
#
# ======================================================================
# Total phones with good resolution (con2=True): 30
# Total phones with poor resolution (con2=False): 20

# %% [markdown]
# Observations:
#
# The features "Px_h" and "Px_w" are respectively the number of pixels in the phone screen in the vertical and horizontal axes.
#
# We created a new feature called "Px" which is the product of the features "Px_h" and "Px_w".
#
# The median has been selected as a threshold in this case.
#
# In case it is too strict, we can choose the mean as a threshold.

# %% [markdown]
# # Task 4 - Obtain the logical conditions for the features "Scr_h" and "Scr_w"

# %%
# Let's tackle these features: "Scr_h", "Scr_w"

# %%
# Create a new feature called "Scr_d" which stores the length of the diagonal of the screen of the phone

import numpy as np

df['Scr_d'] = np.sqrt(df['Scr_h']**2 + df['Scr_w']**2)
df['Scr_d'].head()
# Out:
# 0    3.162278
# 1    2.236068
# 2    2.236068
# 3    5.830952
# 4    5.000000
# Name: Scr_d, dtype: float64

# %%
# Create a histogram of the "Scr_d" feature and also show the quartiles

import matplotlib.pyplot as plt

Q1 = df['Scr_d'].quantile(0.25)
Q2 = df['Scr_d'].quantile(0.50)
Q3 = df['Scr_d'].quantile(0.75)

plt.figure(figsize=(8,5))
plt.hist(df['Scr_d'], bins=20, color='skyblue', edgecolor='black')
plt.axvline(Q1, color='orange', linestyle='--', label=f'Q1 = {Q1:.2f}')
plt.axvline(Q2, color='green', linestyle='--', label=f'Q2 (Median) = {Q2:.2f}')
plt.axvline(Q3, color='red', linestyle='--', label=f'Q3 = {Q3:.2f}')
plt.title('Distribution of Screen Diagonal (Scr_d)')
plt.xlabel('Scr_d')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# The children want phones that have very good screen sizes
# Consider the phones that have screen sizes greater than or equal to the upper quartile value in the data set
# Create a logical condition for this situation and store the logical values as "con3"


con3 = df['Scr_d'] >= df['Scr_d'].quantile(0.75)
con3
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15     True
# 16     True
# 17     True
# 18     True
# 19    False
# 20    False
# 21     True
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34    False
# 35    False
# 36     True
# 37    False
# 38    False
# 39    False
# 40    False
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46    False
# 47     True
# 48     True
# 49     True
# Name: Scr_d, dtype: bool

# %% [markdown]
# Observations:
#
# The features "Scr_h" and "Scr_w" are respectively the height and the width of the phone screen.
#
# We created a new feature called "Scr_d" which is essentially the length of the screen diagonal.
#
# The upper quartile has been selected as a threshold in this case as the children were very particular on this point.
#
# In case it is too strict, we can choose the mean or the median as a threshold.

# %% [markdown]
# # Task 5 - Obtain the logical conditions for the features "PC" and "FC"

# %%
# Let's tackle these features: "PC", "FC"

import matplotlib.pyplot as plt

# %%
# Create a histogram of the "PC" feature and also show the mean and the median

plt.figure(figsize=(8,5))
plt.hist(df['PC'], bins=20, color='skyblue', edgecolor='black')
plt.axvline(df['PC'].mean(), color='red', linestyle='--', label=f"Mean = {df['PC'].mean():.2f}")
plt.axvline(df['PC'].median(), color='green', linestyle='-', label=f"Median = {df['PC'].median():.2f}")
plt.title('Distribution of Primary Camera Resolution (PC)')
plt.xlabel('PC')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# Create a histogram of the "FC" feature and also show the mean and the median


plt.figure(figsize=(8,5))
plt.hist(df['FC'], bins=20, color='lightgreen', edgecolor='black')
plt.axvline(df['FC'].mean(), color='red', linestyle='--', label=f"Mean = {df['FC'].mean():.2f}")
plt.axvline(df['FC'].median(), color='green', linestyle='-', label=f"Median = {df['FC'].median():.2f}")
plt.title('Distribution of Front Camera Resolution (FC)')
plt.xlabel('FC')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# The children want phones that have good primary and front camera resolutions
# Consider the phones that have primary and front camera resolutions greater than or equal to their respective mean values
# Create a logical condition for this situation and store the logical values as "con4"

con4 = (df['PC'] >= df['PC'].mean()) & (df['FC'] >= df['FC'].mean())
con4
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11     True
# 12     True
# 13    False
# 14    False
# 15    False
# 16     True
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25     True
# 26    False
# 27    False
# 28     True
# 29    False
# 30     True
# 31    False
# 32     True
# 33     True
# 34     True
# 35    False
# 36     True
# 37     True
# 38     True
# 39    False
# 40     True
# 41    False
# 42     True
# 43    False
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# 49     True
# dtype: bool

# %% [markdown]
# Observations:
#
# The features "PC" and "FC" are respectively the resolutions of the primary camera and the front camera.
#
# The respective means have been selected as thresholds in this case.
#
# In case it is too strict, we can choose the respective medians as thresholds.

# %% [markdown]
# # Task 6 - Obtain the logical conditions for the features "Int_Mem", "Bty_Pwr" and "RAM"

# %%
# Let's tackle these features: "Int_Mem", "Bty_Pwr", "RAM"

# %%
# Create a histogram of the "Int_Mem" feature and also show the mean and the median

import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df['Int_Mem'], bins=20, color='skyblue', edgecolor='black')
plt.axvline(df['Int_Mem'].mean(), color='red', linestyle='--', label=f"Mean = {df['Int_Mem'].mean():.2f}")
plt.axvline(df['Int_Mem'].median(), color='green', linestyle='-', label=f"Median = {df['Int_Mem'].median():.2f}")
plt.title('Distribution of Internal Memory (Int_Mem)')
plt.xlabel('Int_Mem')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# Create a histogram of the "Bty_Pwr" feature and also show the mean and the median

plt.figure(figsize=(8,5))
plt.hist(df['Bty_Pwr'], bins=20, color='lightgreen', edgecolor='black')
plt.axvline(df['Bty_Pwr'].mean(), color='red', linestyle='--', label=f"Mean = {df['Bty_Pwr'].mean():.2f}")
plt.axvline(df['Bty_Pwr'].median(), color='green', linestyle='-', label=f"Median = {df['Bty_Pwr'].median():.2f}")
plt.title('Distribution of Battery Power (Bty_Pwr)')
plt.xlabel('Bty_Pwr')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# Create a histogram of the "RAM" feature and also show the mean and the median

plt.figure(figsize=(8,5))
plt.hist(df['RAM'], bins=20, color='plum', edgecolor='black')
plt.axvline(df['RAM'].mean(), color='red', linestyle='--', label=f"Mean = {df['RAM'].mean():.2f}")
plt.axvline(df['RAM'].median(), color='green', linestyle='-', label=f"Median = {df['RAM'].median():.2f}")
plt.title('Distribution of RAM')
plt.xlabel('RAM')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# The children want phones that have good internal memory, battery power and RAM
# Consider the phones that have internal memory, battery power and RAM greater than or equal to their respective mean values
# Create a logical condition for this situation and store the logical values as "con5"

con5 = (
    (df['Int_Mem'] >= df['Int_Mem'].mean()) &
    (df['Bty_Pwr'] >= df['Bty_Pwr'].mean()) &
    (df['RAM'] >= df['RAM'].mean())
)
con5
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28     True
# 29     True
# 30     True
# 31    False
# 32     True
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42     True
# 43    False
# 44     True
# 45    False
# 46    False
# 47     True
# 48     True
# 49     True
# dtype: bool

# %% [markdown]
# Observations
#
# The features "Int_Mem", "Bty_Pwr" and "RAM" are respectively the internal memory, battery power and RAM of the phones.
#
# The respective means have been selected as thresholds in this case.
#
# .In case it is too strict, we can choose the respective medians as thresholds

# %% [markdown]
# # Task 7 - Obtain the logical conditions for the features "Depth" and "Weight"

# %%
# Let's tackle these features: "Depth", "Weight"

# %%
# Create a histogram of the "Depth" feature and also show the mean and the median
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df['Depth'], bins=20, color='skyblue', edgecolor='black')
plt.axvline(df['Depth'].mean(), color='red', linestyle='--', label=f"Mean = {df['Depth'].mean():.2f}")
plt.axvline(df['Depth'].median(), color='green', linestyle='-', label=f"Median = {df['Depth'].median():.2f}")
plt.title('Distribution of Phone Depth')
plt.xlabel('Depth')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# Create a histogram of the "Weight" feature and also show the mean and the median

plt.figure(figsize=(8,5))
plt.hist(df['Weight'], bins=20, color='lightgreen', edgecolor='black')
plt.axvline(df['Weight'].mean(), color='red', linestyle='--', label=f"Mean = {df['Weight'].mean():.2f}")
plt.axvline(df['Weight'].median(), color='green', linestyle='-', label=f"Median = {df['Weight'].median():.2f}")
plt.title('Distribution of Phone Weight')
plt.xlabel('Weight')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# The children want phones that are light weight and slim
# Consider the phones that have depth and weight less than or equal to the respective median values in the data set
# Create a logical condition for this situation and store the logical values as "con6"

con6 = (df['Depth'] <= df['Depth'].median()) & (df['Weight'] <= df['Weight'].median())
con6
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# 17    False
# 18    False
# 19    False
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30     True
# 31     True
# 32     True
# 33     True
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41     True
# 42     True
# 43    False
# 44    False
# 45    False
# 46    False
# 47     True
# 48     True
# 49     True
# dtype: bool

# %% [markdown]
# Observations:
#
# The features "Depth" and "Weight" are respectively the depth of the phone and the weight of the phone.
#
# The respective medians have been selected as thresholds in this case.
#
# In case it is too strict, we can choose the respective means as thresholds.

# %% [markdown]
# # Task 8 - Subset the data based on all the logical conditions

# %%
# Subset the dataframe using all the logical conditions that have been stored
# Store the subset of the dataframe as a new dataframe called "df1"

con1 = (df['Blue'] == 1) & (df['Wi_Fi'] == 1) & (df['Tch_Scr'] == 1) & (df['Ext_Mem'] == 1)
con2 = df['Px'] >= df['Px'].median()
con3 = df['Scr_d'] >= df['Scr_d'].quantile(0.75)
con4 = (df['PC'] >= df['PC'].mean()) & (df['FC'] >= df['FC'].mean())

print(con1.head())
print(con2.head())
print(con3.head())
print(con4.head())



df1 = df[con1 & con2 & con3 & con4]
print(df1.head())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Px, dtype: bool
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Scr_d, dtype: bool
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
# Empty DataFrame
# Columns: [PID, Blue, Wi_Fi, Tch_Scr, Ext_Mem, Px_h, Px_w, Scr_h, Scr_w, PC, FC, Int_Mem, Bty_Pwr, RAM, Depth, Weight, Price, Px, con2, Scr_d]
# Index: []

# %%
# Get the dimensions of the dataframe

print("Shape of df1:", df1.shape)
# Out:
# Shape of df1: (0, 20)

# %%
# Sort the dataframe according to the "Price" feature in ascending order and display it

df1_sorted = df1.sort_values(by='Price', ascending=True)

print(df1_sorted)
# Out:
# Empty DataFrame
# Columns: [PID, Blue, Wi_Fi, Tch_Scr, Ext_Mem, Px_h, Px_w, Scr_h, Scr_w, PC, FC, Int_Mem, Bty_Pwr, RAM, Depth, Weight, Price, Px, con2, Scr_d]
# Index: []

# %% [markdown]
# Observations:
#
# Based on all the logical conditions obtained through analysis of the features, we are left with three phones.
#
# The most expensive of these phones is the "TYS938L" model and the least expensive is the "TVF078Y" model.
#
# We could let the children choose from these three phones as per their preferences.

# %% [markdown]
# # Task 9 - Study the variability of the features in the original data set

# %%
# Calculate the ratio of the standard deviation to the mean for all the numerical features in the dataframe
# Store these values in a new series wherein the rows are the features and the only column is the calculated ratio
# Name the series as "deviations"

numeric_df = df.select_dtypes(include=[np.number])

deviations = numeric_df.std() / numeric_df.mean()


deviations_sorted = deviations.sort_values(ascending=False)

print(deviations_sorted)
# Out:
# Int_Mem    1.506514
# Price      0.740868
# PC         0.715716
# FC         0.712184
# RAM        0.479075
# Scr_w      0.407624
# Px         0.398680
# Weight     0.388121
# Scr_d      0.340469
# Scr_h      0.314293
# Depth      0.306072
# Px_h       0.257998
# Bty_Pwr    0.256368
# Px_w       0.256226
# dtype: float64

# %%
# View the "deviations" series after sorting it in descending order

deviations_sorted = deviations.sort_values(ascending=False)

print(deviations_sorted)
# Out:
# Int_Mem    1.506514
# Price      0.740868
# PC         0.715716
# FC         0.712184
# RAM        0.479075
# Scr_w      0.407624
# Px         0.398680
# Weight     0.388121
# Scr_d      0.340469
# Scr_h      0.314293
# Depth      0.306072
# Px_h       0.257998
# Bty_Pwr    0.256368
# Px_w       0.256226
# dtype: float64

# %% [markdown]
# Observations:
#
# The ratio of the standard deviation to the mean of a feature normalises it in a way.
#
# This allows for comparison between multiple features.
#
# The most variable feature in the original data set is the internal memory of the phones.
#
# The least variable feature in the original data set is the number of screen pixels in the horizontal axis.
#
# Although most features don't seem so variable, the prices of the phones are quite variable.
#
# Feel free to investigate what could be the cause of this difference in variability.
#
# Note: We encourage you to extend this analysis further and see what else you can find.
#
# Note: Please refer to the official website of Python and its libraries for various Python documentations.

# %% [markdown]
# # Conclusion
# 1. We have used concepts of descriptive statistics to study and work with a data set that contains mobile phone specifications.
#
# 2. We were able to recommend three phone models to the client which she can then propose to her children.
